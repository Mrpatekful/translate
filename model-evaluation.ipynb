# %% [markdown]
# ## Model evaluation

# %% [markdown]
# This notebook serves as a visualization enviroment for the evolution of a model during a training session.

# %% [markdown]
# #### Imports

# %%
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML

from src.utils.analysis import Analyzer

# %matplotlib inline

# %% [markdown]
# ### Importing serialized data

# %% [markdown]
# Data is saved as Analysis type objects, that carry information about the available data, and it's visualization.

# %%
analyzer = Analyzer(directory='/media/patrik/1EDB65B8599DD93E/model_outputs/unmt_3')
analyzer.show_available_metrics()
# Out:
# > [Train metrics]:	< total_loss > ,
# 			< discriminator_loss > ,
# 			< reguralization_loss > ,
# 			< translation_loss > ,
# 			< auto_encoding_loss > ,
#
# > [Validation metrics]:	< total_loss > ,
# 			< discriminator_loss > ,
# 			< reguralization_loss > ,
# 			< translation_loss > ,
# 			< auto_encoding_loss > ,
# 			< translation_text > ,
# 			< auto_encoding_text > ,
# 			< auto_encoding_latent_state > ,
# 			< auto_encoding_attention > ,
# 			< translation_latent_state > ,
# 			< translation_attention > ,

# %% [markdown]
# ### Visualization

# %% [markdown]
# Visualiaztion of model **loss**

# %%
analyzer.display(metric='translation_loss', mode='train', epoch_range=(0, ))

# %%
analyzer.display(metric='auto_encoding_loss', mode='train', epoch_range=(0, ))

# %%
analyzer.display(metric='discriminator_loss', mode='train', epoch_range=(0, ))

# %% [markdown]
# Visualization of **attention data**, containing the source and target sentences, with the alignment weights

# %%
analyzer.display(metric='translation_attention', mode='validation', epoch_range=(0, ), tokens=['<ENG>'], identifiers=5)
# Out:
# Showing the last element of the epoch range.

# %%
analyzer.display(metric='auto_encoding_attention', mode='validation', epoch_range=(0, ), tokens=['<ENG>'], identifiers=5)
# Out:
# Showing the last element of the epoch range.

# %% [markdown]
# Visualization of **encoder's projected latent state** during auto-encoding and translation

# %%
# with_progression=True, distinct=True,
analyzer.display(metric='auto_encoding_latent_state', with_progression=True, distinct=True, mode='validation', epoch_range=(5, ), analyzer_type='PCA')
# Out:
# Showing the last state of the epoch range.

# %%
# with_progression=True, distinct=True,
analyzer.display(metric='auto_encoding_latent_state', mode='validation', epoch_range=(0, ), with_progression=True, distinct=True, analyzer_type='PCA',  identifiers={'<ENG>': [0, 1, 2], '<FRA>': [0, 1, 2]})
# Out:
# Showing the last state of the epoch range.

# %% [markdown]
# Visualization of the **text** output.

# %%
analyzer.display(metric='translation_text', mode='validation', epoch_range=(0, ))
# Out:
# Showing the last state of the epoch range.
#
# Averaged metrics of <ENG> data with 60 entries:
#
# > BLEU:	0.191
# > accuracy:	0.25
# > precision:	0.254
# > recall:	0.254
# > f_measure:	0.254
#
#
# [0]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: va changer maintenant .
# BLEU: 0.2
#
#
# [1]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: patiente souffre d'hypoxie .
# BLEU: 0.2
#
#
# [2]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: patient souffre d'hypoxie .
# BLEU: 0.2
#
#
# [3]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: réussite est improbable .
# BLEU: 0.2
#
#
# [4]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: usines polluent l'environnement .
# BLEU: 0.2
#
#
# [5]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: malade reprend connaissance .
# BLEU: 0.2
#
#
# [6]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: ce qui m'arrive .
# BLEU: 0.2
#
#
# [7]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: tout du futur .
# BLEU: 0.2
#
#
# [8]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: beaucoup ton aide .
# BLEU: 0.2
#
#
# [9]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: beaucoup votre aide .
# BLEU: 0.2
#
#
# [10]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: croit aux fantômes .
# BLEU: 0.2
#
#
# [11]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: parler plus fort .
# BLEU: 0.2
#
#
# [12]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: bien ton temps .
# BLEU: 0.2
#
#
# [13]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: si l'impensable survenait ?
# BLEU: 0.0
#
#
# [14]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: risquions nos vies .
# BLEU: 0.2
#
#
# [15]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: l'homme que j'attendais .
# BLEU: 0.2
#
#
# [16]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: a été validée .
# BLEU: 0.2
#
#
# [17]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: passagères furent hospitalisées .
# BLEU: 0.2
#
#
# [18]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: l'accepta comme étudiant .
# BLEU: 0.2
#
#
# [19]
# > Input: is the interesting . <EOS>
# > Output: - vous pas .
# > Target: abricotiers ont fleuri .
# BLEU: 0.2
#
#
# [20]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: bien peu dire .
# BLEU: 0.2
#
#
# [21]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: débarrassait la table .
# BLEU: 0.2
#
#
# [22]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: signer le contrat .
# BLEU: 0.2
#
#
# [23]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: prémonition s'avéra exacte .
# BLEU: 0.2
#
#
# [24]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: père oublie tout .
# BLEU: 0.2
#
#
# [25]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: vérifier votre tension .
# BLEU: 0.2
#
#
# [26]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: être professeur d'anglais .
# BLEU: 0.2
#
#
# [27]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: une lettre d'elle .
# BLEU: 0.2
#
#
# [28]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: plus que déçu .
# BLEU: 0.2
#
#
# [29]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: voulais t'être agréable .
# BLEU: 0.2
#
#
# [30]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: pensais vous décevoir .
# BLEU: 0.23
#
#
# [31]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: pensais te décevoir .
# BLEU: 0.2
#
#
# [32]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: tout du marketing .
# BLEU: 0.2
#
#
# [33]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: l'a aimé secrètement .
# BLEU: 0.2
#
#
# [34]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: a tout avalé .
# BLEU: 0.2
#
#
# [35]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: a tout gobé .
# BLEU: 0.2
#
#
# [36]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: signifie intelligence artificielle .
# BLEU: 0.2
#
#
# [37]
# > Input: appreciate is invitation . <EOS>
# > Output: - vous pas .
# > Target: parles , charles .
# BLEU: 0.2
#
#
# [38]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: sortons manger vendredi .
# BLEU: 0.2
#
#
# [39]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: n'approuverait certainement pas .
# BLEU: 0.26
#
#
# [40]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: un point crucial .
# BLEU: 0.2
#
#
# [41]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: réduiront leurs dépenses .
# BLEU: 0.2
#
#
# [42]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: est mère d'apprentissage .
# BLEU: 0.2
#
#
# [43]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: d'extraordinaire n'est arrivé .
# BLEU: 0.2
#
#
# [44]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: d'extraordinaire n'est survenu .
# BLEU: 0.2
#
#
# [45]
# > Input: appreciate the invitation . <EOS>
# > Output: - vous pas .
# > Target: dommage qu'ils divorcent .
# BLEU: 0.2
#
#
# [46]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: pourra commencer bientôt .
# BLEU: 0.2
#
#
# [47]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: hors de question .
# BLEU: 0.2
#
#
# [48]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: vous cherche partout .
# BLEU: 0.23
#
#
# [49]
# > Input: is is invitation . <EOS>
# > Output: - vous pas .
# > Target: te cherche partout .
# BLEU: 0.2
#
#
# [50]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: l'économie à l'université .
# BLEU: 0.2
#
#
# [51]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: la touche finale .
# BLEU: 0.2
#
#
# [52]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: quelque chose dans l'hotel
# BLEU: 0.0
#
#
# [53]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: roman m'est incompréhensible .
# BLEU: 0.2
#
#
# [54]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: comportement m'énerve vraiment .
# BLEU: 0.2
#
#
# [55]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: tremble de froid .
# BLEU: 0.2
#
#
# [56]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: sauta sur l'occasion .
# BLEU: 0.2
#
#
# [57]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: étudie l'informatique linguistique .
# BLEU: 0.2
#
#
# [58]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: fonctionnera selon l'horaire .
# BLEU: 0.2
#
#
# [59]
# > Input: is the invitation . <EOS>
# > Output: - vous pas .
# > Target: attentif aux pickpockets .
# BLEU: 0.2
#
#
# Averaged metrics of <FRA> data with 60 entries:
#
# > BLEU:	0.195
# > accuracy:	0.258
# > precision:	0.263
# > recall:	0.263
# > f_measure:	0.263
#
#
# [0]
# > Input: - vous pas ça . <EOS>
# > Output: is the immediately .
# > Target: is rapidly approaching .
# BLEU: 0.23
#
#
# [1]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: conducts electricity well .
# BLEU: 0.2
#
#
# [2]
# > Input: - tu pas tom . <EOS>
# > Output: is the immediately .
# > Target: interrupt our conversation .
# BLEU: 0.2
#
#
# [3]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: chocolate contains vitamins .
# BLEU: 0.2
#
#
# [4]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: produced many scientists .
# BLEU: 0.2
#
#
# [5]
# > Input: - vous pas ça . <EOS>
# > Output: is the immediately .
# > Target: collected various information .
# BLEU: 0.2
#
#
# [6]
# > Input: - tu pas maintenant . <EOS>
# > Output: not the immediately .
# > Target: a professional photographer .
# BLEU: 0.2
#
#
# [7]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: an important announcement .
# BLEU: 0.2
#
#
# [8]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: englishmen are conservative .
# BLEU: 0.2
#
#
# [9]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: kaddafi escaped unharmed .
# BLEU: 0.2
#
#
# [10]
# > Input: - - pas ça . <EOS>
# > Output: is the immediately .
# > Target: carry weather reports .
# BLEU: 0.2
#
#
# [11]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: make yourself comfortable .
# BLEU: 0.2
#
#
# [12]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: a successful businesswoman .
# BLEU: 0.2
#
#
# [13]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: company produces microchips .
# BLEU: 0.2
#
#
# [14]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: a frightening possibility .
# BLEU: 0.2
#
#
# [15]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: certainly one possibility .
# BLEU: 0.2
#
#
# [16]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: implications are frightening .
# BLEU: 0.2
#
#
# [17]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: president appeared powerless .
# BLEU: 0.2
#
#
# [18]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: conversation never happened .
# BLEU: 0.2
#
#
# [19]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: sensed mary's disappointment .
# BLEU: 0.2
#
#
# [20]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the yesterday .
# > Target: nervousness was noticeable .
# BLEU: 0.2
#
#
# [21]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: appreciate your understanding .
# BLEU: 0.2
#
#
# [22]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: couldn't possibly understand .
# BLEU: 0.2
#
#
# [23]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: not interrupting anything .
# BLEU: 0.23
#
#
# [24]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: suggestion seems reasonable .
# BLEU: 0.2
#
#
# [25]
# > Input: - tu vous voir . <EOS>
# > Output: is the immediately .
# > Target: you contradicting yourself ?
# BLEU: 0.0
#
#
# [26]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: driving causes accidents .
# BLEU: 0.2
#
#
# [27]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: like watching television .
# BLEU: 0.2
#
#
# [28]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: won't change anything .
# BLEU: 0.2
#
#
# [29]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: underestimate your opponent .
# BLEU: 0.2
#
#
# [30]
# > Input: - tu pas maintenant . <EOS>
# > Output: not the immediately .
# > Target: established many colonies .
# BLEU: 0.2
#
#
# [31]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: investigation is required .
# BLEU: 0.2
#
#
# [32]
# > Input: il pas pas ça . <EOS>
# > Output: not the immediately .
# > Target: became financially independent .
# BLEU: 0.2
#
#
# [33]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: a professional photographer .
# BLEU: 0.2
#
#
# [34]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: unexpected has happened .
# BLEU: 0.2
#
#
# [35]
# > Input: - tu la ça . <EOS>
# > Output: is the immediately .
# > Target: student's studying sociology .
# BLEU: 0.2
#
#
# [36]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: definitely something else .
# BLEU: 0.2
#
#
# [37]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: hasn't regained consciousness .
# BLEU: 0.2
#
#
# [38]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: increased soon afterward .
# BLEU: 0.2
#
#
# [39]
# > Input: - tu pas ça . <EOS>
# > Output: not the yesterday .
# > Target: underestimate your importance .
# BLEU: 0.2
#
#
# [40]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: dictionaries are allowed .
# BLEU: 0.2
#
#
# [41]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: driving prevents accidents .
# BLEU: 0.2
#
#
# [42]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: happening too quickly .
# BLEU: 0.2
#
#
# [43]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: studies contemporary literature .
# BLEU: 0.2
#
#
# [44]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: achievements were acknowledged .
# BLEU: 0.2
#
#
# [45]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: english requires patience .
# BLEU: 0.2
#
#
# [46]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: started shaking uncontrollably .
# BLEU: 0.2
#
#
# [47]
# > Input: - tu la maintenant . <EOS>
# > Output: is the immediately .
# > Target: the underlined sentences .
# BLEU: 0.23
#
#
# [48]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: always anticipating trouble .
# BLEU: 0.2
#
#
# [49]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: often causes accidents .
# BLEU: 0.2
#
#
# [50]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: on your anniversary .
# BLEU: 0.2
#
#
# [51]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: encountered unexpected obstacles .
# BLEU: 0.2
#
#
# [52]
# > Input: - tu pas maintenant . <EOS>
# > Output: not the immediately .
# > Target: printed the proclamation .
# BLEU: 0.23
#
#
# [53]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: requires careful consideration .
# BLEU: 0.2
#
#
# [54]
# > Input: il vous pas ça . <EOS>
# > Output: is the immediately .
# > Target: studies computational linguistics .
# BLEU: 0.2
#
#
# [55]
# > Input: - tu pas ça . <EOS>
# > Output: not the immediately .
# > Target: elevators operate automatically .
# BLEU: 0.2
#
#
# [56]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: underestimate his determination .
# BLEU: 0.2
#
#
# [57]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: passengers were hospitalized .
# BLEU: 0.2
#
#
# [58]
# > Input: - tu pas ça . <EOS>
# > Output: is the immediately .
# > Target: columbus discovered america .
# BLEU: 0.2
#
#
# [59]
# > Input: - tu pas maintenant . <EOS>
# > Output: is the immediately .
# > Target: acquisition requires creativity .
# BLEU: 0.2
