# %%
from src.utils.analysis import TextAnalyzer

# %% [markdown]
# ## English

# %% [markdown]
# **Tokenized** english data, with full FastText vocab.

# %%
TextAnalyzer.create_report(corpora='/media/patrik/1EDB65B8599DD93E/data/eng/ENG_DATA',
                           vocab='/media/patrik/1EDB65B8599DD93E/data/eng/VOCAB_ENG')
# Out:
# ...
# Checking vocab coverage: : 435099it [00:00, 1241027.73it/s]
# Number of lines:                                    20634598
# Average line length:                                25.72
# Number of unique words in the corpora:              435099
# Number of words, with an occurrence of less than 5: 131219 (30.16% of unique words)
# Number of singleton words:                          2081 (0.4783% of unique words)
# Vocab coverage:                                     60.25%
# Vocab usage:                                        10.41%

# %% [markdown]
# **Synchronized** english data with clipped FastText vocab.

# %%
TextAnalyzer.create_report(corpora='/media/patrik/1EDB65B8599DD93E/data/eng/ENG_DATA_SYNC', 
                           vocab='/media/patrik/1EDB65B8599DD93E/data/eng/wiki.en.vec_synced_validated')

# %% [markdown]
# ## French

# %% [markdown]
# **Tokenized** french data, with full FastText vocab.

# %%
TextAnalyzer.create_report(corpora='/media/patrik/1EDB65B8599DD93E/data/fra/FRA_DATA', 
                           vocab='/media/patrik/1EDB65B8599DD93E/data/fra/VOCAB_FRA')
# Out:
# ...
# Checking vocab coverage: : 1273301it [00:00, 1384224.31it/s]
# Number of lines:                                    19681073
# Average line length:                                28.79
# Number of unique words in the corpora:              1273301
# Number of words, with an occurrence of less than 5: 920806 (72.32% of unique words)
# Number of singleton words:                          598136 (46.98% of unique words)
# Vocab coverage:                                     27.9%
# Vocab usage:                                        31.48%

# %% [markdown]
# **Synchronized** french data, with clipped FastText vocab.

# %%
TextAnalyzer.create_report(corpora='/media/patrik/1EDB65B8599DD93E/data/fra/FRA_DATA_SYNC', 
                           vocab='/media/patrik/1EDB65B8599DD93E/data/fra/wiki.fr.vec_synced_validated')
