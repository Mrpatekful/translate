# %% [markdown]
# ## Model evaluation

# %% [markdown]
# This notebook serves as a visualization enviroment for the evolution of a model during a training session.

# %% [markdown]
# #### Imports

# %%
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML

from src.utils.analysis import Analyzer

# %matplotlib inline

# %% [markdown]
# ### Importing serialized data

# %% [markdown]
# Data is saved as Analysis type objects, that carry information about the available data, and it's visualization.

# %%
analyzer = Analyzer('/home/patrik/GitHub/nmt-BMEVIAUAL01/logs/unmt_0/outputs')
analyzer.show_available_metrics()
# Out:
# > [Train metrics]:	< total_loss > ,
# 			< discriminator_loss > ,
# 			< reguralization_loss > ,
# 			< translation_loss > ,
# 			< auto_encoding_loss > ,
#
# > [Validation metrics]:	< total_loss > ,
# 			< discriminator_loss > ,
# 			< reguralization_loss > ,
# 			< translation_loss > ,
# 			< auto_encoding_loss > ,
# 			< translation_text > ,
# 			< auto_encoding_text > ,
# 			< auto_encoding_attention > ,
# 			< translation_attention > ,

# %%
analyzer.plot(metric='auto_encoding_loss', mode='train', epoch_range=(0, ))

# %%
analyzer.plot(metric='auto_encoding_loss', mode='validation', epoch_range=(0, ))

# %%
analyzer.plot(metric='discriminator_loss', mode='validation', epoch_range=(0, ))

# %%
analyzer.plot(metric='auto_encoding_attention', mode='validation', epoch_range=(0, 4), tokens=['<ENG>'], identifiers=[0])
# Out:
# Showing the last element of the epoch range.

# %% [markdown]
# ### Visualization

# %%
analyzer.plot(metric='alignment_weights')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-99fd10ad11be> in <module>()
# ----> 1 analyzer.plot(metric='alignment_weights')
#
# TypeError: plot() missing 1 required positional argument: 'mode'

# %%
a = {'a':[1, 2, 3, 4], 'b':[0, 0, 0, 0]}
print(list(zip(*list(a.items()))))
a = ['asd', 'b']
print('%d %s' % (len(a), ' '.join(a)))

# %%
import matplotlib.animation as animation

fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# %%
def init():
    line.set_data([], [])
    return (line,)

def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

anim

# %%
a = {'asd': 1, 'bb': 2}
a = [(key, a[key]) for key in a]
print(a)
# Out:
# [('asd', 1), ('bb', 2)]
